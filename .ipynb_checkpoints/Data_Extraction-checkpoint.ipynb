# %%
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm
import pickle

# %%
filenames = []

for file in os.listdir("t20_data"):
    filenames.append(os.path.join("t20_data", file))

# %%
len(filenames)
# Out:
# 1433

# %%
final_df = pd.DataFrame()

counter = 1

for file in tqdm(filenames):
    with open(file, "r") as f:
        df = pd.json_normalize(safe_load(f))
        df["match_id"] = counter
        final_df = pd.concat([final_df, df])
        counter += 1

final_df  # The last entry of the dataset has some error, but it doesn't matter it's just 1 entry
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████▉| 1432/1433 [02:37<00:00,  9.07it/s]
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[11], line 7
#       5 for file in tqdm(filenames):
#       6     with open(file, "r") as f:
# ----> 7         df = pd.json_normalize(safe_load(f))
#       8         df["match_id"] = counter
#       9         final_df = pd.concat([final_df, df])
#
# File D:\Python\Lib\site-packages\pandas\io\json\_normalize.py:445, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     443     data = list(data)
#     444 else:
# --> 445     raise NotImplementedError
#     447 # check to see if a simple recursive function is possible to
#     448 # improve performance (see #15621) but only for cases such
#     449 # as pd.Dataframe(data) or pd.Dataframe(data, sep)
# ...

# %%
final_df.head(2)
# Out:
#                                              innings  meta.data_version  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0  [{'1st innings': {'team': 'Australia', 'delive...                0.9
#
#   meta.created  meta.revision    info.dates info.gender info.match_type  \
# 0   2017-02-18              2  [2017-02-17]        male             T20
# 0   2017-02-19              2  [2017-02-19]        male             T20
#
#    info.outcome.by.wickets info.outcome.winner  info.overs  ...  \
# 0                      5.0           Sri Lanka          20  ...
# 0                      2.0           Sri Lanka          20  ...
#
#   info.outcome.by.runs info.match_type_number info.neutral_venue  \
# 0                  NaN                    NaN                NaN
# 0                  NaN                    NaN                NaN
#
#   info.outcome.method info.outcome.result info.outcome.eliminator  \
# ...

# %%
backup = final_df.copy()

# %%
final_df.drop(columns=[
    'meta.data_version',
    'meta.created',
    'meta.revision',
    'info.outcome.bowl_out',
    'info.bowl_out',
    'info.supersubs.South Africa',
    'info.supersubs.New Zealand',
    'info.outcome.eliminator',
    'info.outcome.result',
    'info.outcome.method',
    'info.neutral_venue',
    'info.match_type_number',
    'info.outcome.by.runs',
    'info.outcome.by.wickets'
],inplace=True)

# %%
final_df.head(2)
# Out:
#                                              innings    info.dates  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
#
#   info.gender info.match_type info.outcome.winner  info.overs  \
# 0        male             T20           Sri Lanka          20
# 0        male             T20           Sri Lanka          20
#
#   info.player_of_match              info.teams info.toss.decision  \
# 0      [DAS Gunaratne]  [Australia, Sri Lanka]              field
# 0      [DAS Gunaratne]  [Australia, Sri Lanka]              field
#
#   info.toss.winner            info.umpires                      info.venue  \
# 0        Sri Lanka  [MD Martell, P Wilson]        Melbourne Cricket Ground
# 0        Sri Lanka   [SD Fry, SJ Nogajski]  Simonds Stadium, South Geelong
#
#    match_id info.city
# 0         1       NaN
# 0         2  Victoria

# %%
final_df["info.gender"].value_counts()
# Out:
# info.gender
# male      966
# female    466
# Name: count, dtype: int64

# %%
final_df = final_df[final_df["info.gender"] == "male"]

final_df.drop(columns= ["info.gender"], inplace = True)
# Out:
# C:\Users\DIWAKAR SINGH\AppData\Local\Temp\ipykernel_25884\2864370367.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns= ["info.gender"], inplace = True)

# %%
final_df.head(2)
# Out:
#                                              innings    info.dates  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
#
#   info.match_type info.outcome.winner  info.overs info.player_of_match  \
# 0             T20           Sri Lanka          20      [DAS Gunaratne]
# 0             T20           Sri Lanka          20      [DAS Gunaratne]
#
#                info.teams info.toss.decision info.toss.winner  \
# 0  [Australia, Sri Lanka]              field        Sri Lanka
# 0  [Australia, Sri Lanka]              field        Sri Lanka
#
#              info.umpires                      info.venue  match_id info.city
# 0  [MD Martell, P Wilson]        Melbourne Cricket Ground         1       NaN
# 0   [SD Fry, SJ Nogajski]  Simonds Stadium, South Geelong         2  Victoria

# %%
final_df.shape
# Out:
# (966, 13)

# %%
final_df["info.match_type"].value_counts()
# Out:
# info.match_type
# T20    966
# Name: count, dtype: int64

# %%
final_df["info.overs"].value_counts()
# Out:
# info.overs
# 20    963
# 50      3
# Name: count, dtype: int64

# %%
final_df = final_df[final_df["info.overs"] == 20]

final_df.drop(columns = ["info.match_type", "info.overs"], inplace = True)
# Out:
# C:\Users\DIWAKAR SINGH\AppData\Local\Temp\ipykernel_25884\2542357869.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns = ["info.match_type", "info.overs"], inplace = True)

# %%
final_df.head(2)
# Out:
#                                              innings    info.dates  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
#
#   info.outcome.winner info.player_of_match              info.teams  \
# 0           Sri Lanka      [DAS Gunaratne]  [Australia, Sri Lanka]
# 0           Sri Lanka      [DAS Gunaratne]  [Australia, Sri Lanka]
#
#   info.toss.decision info.toss.winner            info.umpires  \
# 0              field        Sri Lanka  [MD Martell, P Wilson]
# 0              field        Sri Lanka   [SD Fry, SJ Nogajski]
#
#                        info.venue  match_id info.city
# 0        Melbourne Cricket Ground         1       NaN
# 0  Simonds Stadium, South Geelong         2  Victoria

# %%
pickle.dump(final_df, open("t20_cleaned_dataset_level1.pkl", "wb"))

# %% [markdown]
# ## Load Dataset

# %%
matches = pickle.load(open("t20_cleaned_dataset_level1.pkl", "rb"))

matches.iloc[0]["innings"][0]["1st innings"]["deliveries"]
# Out:
# [{0.1: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.2: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.3: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {0.4: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {0.5: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.6: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#  {1.1: {'batsman': 'M Klinger',
#    'bowler': 'KMDN Kulasekara',
# ...

# %%
count = 1

delivery_df = pd.DataFrame()

for index, row in matches.iterrows():
    
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    
    for ball in row["innings"][0]["1st innings"]["deliveries"]:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row["innings"][0]["1st innings"]["team"])
            teams.append(row["info.teams"])
            ball_of_match.append(key)
            batsman.append(ball[key]["batsman"])
            bowler.append(ball[key]["bowler"])
            runs.append(ball[key]["runs"]["total"])
            city.append(row["info.city"])
            venue.append(row["info.venue"])
            
            try:
                player_of_dismissed.append(ball[key]["wicket"]["player_out"])
            except:
                player_of_dismissed.append("0")
    
    count += 1
    
    loop_df = pd.DataFrame({
        "match_id": match_id,
        "teams": teams,
        "batting_team": batting_team,
        "ball": ball_of_match,
        "batsman": batsman,
        "bowler": bowler,
        "runs": runs,
        "player_dismissed": player_of_dismissed,
        "city": city,
        "venue": venue
    })
    
    delivery_df = pd.concat([delivery_df, loop_df])

# %%
matches.head(2)
# Out:
#                                              innings    info.dates  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
#
#   info.outcome.winner info.player_of_match              info.teams  \
# 0           Sri Lanka      [DAS Gunaratne]  [Australia, Sri Lanka]
# 0           Sri Lanka      [DAS Gunaratne]  [Australia, Sri Lanka]
#
#   info.toss.decision info.toss.winner            info.umpires  \
# 0              field        Sri Lanka  [MD Martell, P Wilson]
# 0              field        Sri Lanka   [SD Fry, SJ Nogajski]
#
#                        info.venue  match_id info.city
# 0        Melbourne Cricket Ground         1       NaN
# 0  Simonds Stadium, South Geelong         2  Victoria

# %%
delivery_df.head()
# Out:
#    match_id                   teams batting_team  ball    batsman      bowler  \
# 0         1  [Australia, Sri Lanka]    Australia   0.1   AJ Finch  SL Malinga
# 1         1  [Australia, Sri Lanka]    Australia   0.2   AJ Finch  SL Malinga
# 2         1  [Australia, Sri Lanka]    Australia   0.3   AJ Finch  SL Malinga
# 3         1  [Australia, Sri Lanka]    Australia   0.4  M Klinger  SL Malinga
# 4         1  [Australia, Sri Lanka]    Australia   0.5  M Klinger  SL Malinga
#
#    runs player_dismissed city                     venue
# 0     0                0  NaN  Melbourne Cricket Ground
# 1     0                0  NaN  Melbourne Cricket Ground
# 2     1                0  NaN  Melbourne Cricket Ground
# 3     2                0  NaN  Melbourne Cricket Ground
# 4     0                0  NaN  Melbourne Cricket Ground

# %%
delivery_df["match_id"].value_counts()
# Out:
# match_id
# 168    134
# 8      134
# 690    134
# 370    134
# 788    133
#       ...
# 903     37
# 187     31
# 818     29
# 432     16
# 699      2
# Name: count, Length: 953, dtype: int64

# %%
len(delivery_df["player_dismissed"].unique())
# Out:
# 1198

# %%
delivery_df.shape
# Out:
# (115325, 10)

# %%
delivery_df.head(2)
# Out:
#    match_id                   teams batting_team  ball   batsman      bowler  \
# 0         1  [Australia, Sri Lanka]    Australia   0.1  AJ Finch  SL Malinga
# 1         1  [Australia, Sri Lanka]    Australia   0.2  AJ Finch  SL Malinga
#
#    runs player_dismissed city                     venue
# 0     0                0  NaN  Melbourne Cricket Ground
# 1     0                0  NaN  Melbourne Cricket Ground

# %%
def bowl(row):
    for team in row["teams"]:
        if team != row["batting_team"]:
            return team

# %%
delivery_df["bowling_team"] = delivery_df.apply(bowl, axis = 1)

# %%
delivery_df.drop(columns = ["teams"], inplace = True)

delivery_df.head(2)
# Out:
#    match_id batting_team  ball   batsman      bowler  runs player_dismissed  \
# 0         1    Australia   0.1  AJ Finch  SL Malinga     0                0
# 1         1    Australia   0.2  AJ Finch  SL Malinga     0                0
#
#   city                     venue bowling_team
# 0  NaN  Melbourne Cricket Ground    Sri Lanka
# 1  NaN  Melbourne Cricket Ground    Sri Lanka

# %%
delivery_df["batting_team"].unique()
# Out:
# array(['Australia', 'Hong Kong', 'Zimbabwe', 'India', 'Bangladesh',
#        'New Zealand', 'South Africa', 'England', 'West Indies', 'Ireland',
#        'Afghanistan', 'Pakistan', 'United Arab Emirates', 'Scotland',
#        'Oman', 'Papua New Guinea', 'Sri Lanka', 'Netherlands', 'Nepal',
#        'Vanuatu', 'Philippines', 'United States of America', 'Germany',
#        'Ghana', 'Uganda', 'Kenya', 'Namibia', 'Nigeria', 'Botswana',
#        'Guernsey', 'Denmark', 'Jersey', 'Italy', 'Norway', 'Thailand',
#        'Malaysia', 'Maldives', 'Singapore', 'Kuwait', 'Bermuda', 'Canada',
#        'Cayman Islands', 'Portugal', 'Gibraltar', 'Spain', 'Bhutan',
#        'Qatar', 'Iran', 'Belgium', 'Isle of Man', 'Bulgaria', 'Romania'],
#       dtype=object)

# %%
# Popular 10 teams of the world
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'    
]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df.shape
# Out:
# (63888, 10)

# %%
output = delivery_df[["match_id", "batting_team", "bowling_team", "ball", "runs", "player_dismissed", "city", "venue"]]

# %%
output.head()
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed city  \
# 0         1    Australia    Sri Lanka   0.1     0                0  NaN
# 1         1    Australia    Sri Lanka   0.2     0                0  NaN
# 2         1    Australia    Sri Lanka   0.3     1                0  NaN
# 3         1    Australia    Sri Lanka   0.4     2                0  NaN
# 4         1    Australia    Sri Lanka   0.5     0                0  NaN
#
#                       venue
# 0  Melbourne Cricket Ground
# 1  Melbourne Cricket Ground
# 2  Melbourne Cricket Ground
# 3  Melbourne Cricket Ground
# 4  Melbourne Cricket Ground

# %%
pickle.dump(output, open("Cleaned_t20_Dataset.pkl", "wb"))
